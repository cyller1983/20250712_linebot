# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="天空為什麼是藍的?"
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[1], line 6
#       3 # The client gets the API key from the environment variable `GEMINI_API_KEY`.
#       4 client = genai.Client(api_key='GEMINI_API_KEY')
# ----> 6 response = client.models.generate_content(
#       7     model="gemini-2.5-flash", contents="天空為什麼是藍的?"
#       8 )
#       9 print(response.text)
#
# File ~/miniconda3/envs/line_bot/lib/python3.12/site-packages/google/genai/models.py:5835, in Models.generate_content(self, model, contents, config)
#    5833 while remaining_remote_calls_afc > 0:
#    5834   i += 1
# -> 5835   response = self._generate_content(
#    5836       model=model, contents=contents, config=parsed_config
#    5837   )
#    5838   logger.info(f'AFC remote call {i} is done.')
#    5839   remaining_remote_calls_afc -= 1
#
# File ~/miniconda3/envs/line_bot/lib/python3.12/site-packages/google/genai/models.py:4761, in Models._generate_content(self, model, contents, config)
#    4758 request_dict = _common.convert_to_dict(request_dict)
#    4759 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4761 response = self._api_client.request(
#    4762     'post', path, request_dict, http_options
#    4763 )
#    4765 response_dict = '' if not response.body else json.loads(response.body)
#    4767 if self._api_client.vertexai:
#
# File ~/miniconda3/envs/line_bot/lib/python3.12/site-packages/google/genai/_api_client.py:1177, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1167 def request(
#    1168     self,
#    1169     http_method: str,
#    (...)   1172     http_options: Optional[HttpOptionsOrDict] = None,
#    1173 ) -> SdkHttpResponse:
#    1174   http_request = self._build_request(
#    1175       http_method, path, request_dict, http_options
#    1176   )
# -> 1177   response = self._request(http_request, http_options, stream=False)
#    1178   response_body = (
#    1179       response.response_stream[0] if response.response_stream else ''
#    1180   )
#    1181   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/miniconda3/envs/line_bot/lib/python3.12/site-packages/google/genai/_api_client.py:997, in BaseApiClient._request(self, http_request, http_options, stream)
#     994     retry = tenacity.Retrying(**retry_kwargs)
#     995     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# --> 997 return self._retry(self._request_once, http_request, stream)
#
# File ~/miniconda3/envs/line_bot/lib/python3.12/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File ~/miniconda3/envs/line_bot/lib/python3.12/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~/miniconda3/envs/line_bot/lib/python3.12/site-packages/tenacity/__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     416 retry_exc = self.retry_error_cls(fut)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File ~/miniconda3/envs/line_bot/lib/python3.12/site-packages/tenacity/__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File ~/miniconda3/envs/line_bot/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/miniconda3/envs/line_bot/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/miniconda3/envs/line_bot/lib/python3.12/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/miniconda3/envs/line_bot/lib/python3.12/site-packages/google/genai/_api_client.py:974, in BaseApiClient._request_once(self, http_request, stream)
#     966 else:
#     967   response = self._httpx_client.request(
#     968       method=http_request.method,
#     969       url=http_request.url,
#    (...)    972       timeout=http_request.timeout,
#     973   )
# --> 974   errors.APIError.raise_for_response(response)
#     975   return HttpResponse(
#     976       response.headers, response if stream else [response.text]
#     977   )
#
# File ~/miniconda3/envs/line_bot/lib/python3.12/site-packages/google/genai/errors.py:105, in APIError.raise_for_response(cls, response)
#     103 status_code = response.status_code
#     104 if 400 <= status_code < 500:
# --> 105   raise ClientError(status_code, response_json, response)
#     106 elif 500 <= status_code < 600:
#     107   raise ServerError(status_code, response_json, response)
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}
